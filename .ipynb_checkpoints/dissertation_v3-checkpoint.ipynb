# %%
import os
import re
from collections import defaultdict
from pprint import pprint

import matplotlib.pyplot as plt
import nltk
import numpy as np
import omdb
import pandas as pd
import seaborn as sns
import sklearn
import spacy
from gensim.models import KeyedVectors, Word2Vec
from googleapiclient.discovery import build
from nltk.corpus import stopwords
from sklearn.cluster import KMeans
from sklearn.decomposition import PCA
from sklearn.metrics.pairwise import cosine_similarity
from textblob import TextBlob
from wordcloud import WordCloud



pd.set_option('display.max_colwidth', None)
SPECIAL_CHARS = '[^A-Za-z0-9 ]+'
STOP_WORDS = stopwords.words('english')

# use pre-trained corpus to help tokenise words
nlp = spacy.load('en_core_web_sm')

path = "GoogleNews-vectors-negative300.bin"
w2v = KeyedVectors.load_word2vec_format(path, binary=True)
# It is much faster take less than 2 minutes


OMDB_API_KEY = os.environ.get('OMDB_API_KEY')
omdb.set_default('apikey', OMDB_API_KEY)

YOUTUBE_API_KEY = os.environ.get('YOUTUBE_API_KEY')
youtube = build('youtube','v3',developerKey=YOUTUBE_API_KEY)

# %% [markdown]
# # 2. Functions

# %%
def preprocess_text(text):
    """
    Take out stopwords.
    Take out punctuations and special characters.
    """
    SPECIAL_CHARS = '[^A-Za-z0-9 ]+'
    STOP_WORDS = stopwords.words('english')
    text = text.lower().split(' ')
    temp = [word for word in text if word not in STOP_WORDS]
    text = ' '.join(temp)
    text = re.sub(SPECIAL_CHARS, '', text)
    text = [w for w in text.split(' ') if w not in ['im','dont','cant','wont','shouldnt','couldnt','wouldnt']]
    return_text = ' '.join(text)
    return return_text

# %%
def preprocess_text_v2(text):
    """
    Take out fewer stopwords.
    Take out punctuations and special characters.
    """
    text = text.lower()
    text = re.sub(SPECIAL_CHARS, '', text)
#     text = [w for w in text.split(' ') if w not in ['im','dont','cant','wont','shouldnt','couldnt','wouldnt']]
#     return_text = ' '.join(text)
    return text

# %%
def tokenise(doc):
    return [token.text for token in nlp(doc)]

# %%
def tokenise_lemma(doc):
    """
    Use spacy as the nlp object to tokenise each doc
    Lemmatise each words
    """
    return ' '.join([token.lemma_ for token in nlp(doc)])

# %%
# this is one way to get each title's vector representation
# more investagtion is needed later.

def get_vectors(first_map, second_map):
    """
    Use tokenised words to get vectors representations from the pretrained model (i.e. second_map).
    Average the vector representation of the description as the representation of the document 
    (i.e. each movie title's representation is the mean of vectors of each words in its description)
    """
    first_vec  = dict()
    for title, description in first_map.items():
        temp = list()
        for element in description: #element = tokenised words
            try:
                temp.append(second_map[element]) #secondmap is w2v model which should have a responding word vecotr for the tokenise word
            except KeyError:
                pass
        first_vec[title] = np.mean(temp, axis=0)
    
    return first_vec

# %%
def search(name, df):
    return df.loc[df['title'].str.lower()==name.lower()]

# %%
def get_topN_similar(lookup_id, title_vec, df, N=10):
    lookup_id = lookup_id.lower()
    sim = list()
    lookup_map = title_vec
    subject_map = title_vec 
        
    for uid, vec in lookup_map.items():
        thisSim = cosine_similarity(vec.reshape(1, -1), subject_map[lookup_id].reshape(1, -1))
        org = search(uid, df).originals.values.tolist()[0]
        gen = search(uid, df).genres.values.tolist()[0]
        year = search(uid, df).year.values.tolist()[0]
        sim.append((uid, thisSim[0][0], org, gen, year))
    sim = sorted(sim, key=lambda x: x[1], reverse=True)[:N+1]
    returnDf = pd.DataFrame(columns=['title','similarity','originals','genres', 'year'],
                           data = sim)
    return returnDf

# %%
def get_most_similar(lookup_id, title_vec, df):

    sim = list()
    lookup_map = title_vec
    subject_map = title_vec 
        
    for uid, vec in lookup_map.items():
        thisSim = cosine_similarity(vec.reshape(1, -1), subject_map[lookup_id].reshape(1, -1))
        org = search(uid, df).originals.values
        gen = search(uid, df).genres.values
        sim.append((uid, thisSim[0][0], org, gen))

    return sorted(sim, key=lambda x: x[1], reverse=True)

# %%
def filter_df(keyword):
    """
    Return a dataframe with the filtered result.
    The input value is case-insensitive. 
    """
    if type(keyword) == list:
        return netflixDf.loc[netflixDf['title'].isin(keyword)]
    else:
        return netflixDf.loc[netflixDf['title'].str.lower().isin([keyword.lower()])]

# %%
def markerX(key, values):
    return netflixDf.loc[netflixDf[key].str.lower().isin(values)].sort_values(by='pca_2', ascending=False)

def others(key, values):
    return netflixDf.loc[~netflixDf[key].str.lower().isin(values)]

# %%
def vec_representation(DF):
    '''
    This function takes a dataframe to produce a title-vector mapping dictionary.
    For the use of the later recommender systems. 
    '''
    TkDocs = [tokenise(doc) for doc in DF.everything.values.tolist()] #tokenise 
    # mapping out the title and each description. so later on i can search 
    Map = dict(zip(DF['title'].str.lower().tolist(), TkDocs))
    # lower the title (easy for search)
    titleVec = get_vectors(Map, w2v)
    return titleVec

# %%
def omdb_get(title,year, media_type):
    movie_info = omdb.get(title=title, year = year, fullplot = True, media_type=media_type)
    temp = pd.DataFrame(data=[movie_info])
    return temp

# %% [markdown]
# # Pipeline Functions

# %%
def show_values_on_bars(axs, h_v="v", space=0.4, round_out=True):
    def _show_on_single_plot(ax):
        if h_v == "v":
            for p in ax.patches:
                _x = p.get_x() + p.get_width() / 2
                _y = p.get_y() + p.get_height()
                if round_out == True:
                    value = int(p.get_height())
                    ax.text(_x, _y, value, ha="center") 
                else:
                    value = p.get_height()
                    ax.text(_x, _y, value, ha="center") 
        elif h_v == "h":
            for p in ax.patches:
                _x = p.get_x() + p.get_width() + float(space)
                _y = p.get_y() + p.get_height()
                if round_out == True:
                    value = int(p.get_width())
                    ax.text(_x, _y, value, ha="left") 
                else:
                    value = p.get_width()
                    ax.text(_x, _y, value, ha="center") 

    if isinstance(axs, np.ndarray):
        for idx, ax in np.ndenumerate(axs):
            _show_on_single_plot(ax)
    else:
        _show_on_single_plot(axs)

# %%
def function_year_analysis(df, save=False, title=None):
    title = df.title.tolist()[0]
    year = pd.DataFrame()
    year['year'] = df.year.value_counts().index.tolist()
    year['count'] = df.year.value_counts().tolist()
    year = year.astype(int).sort_values(by='year')
    fig, ax = plt.subplots(figsize=(10,6))
    sns.barplot(x='year', y='count', data=year, ax=ax)
    show_values_on_bars(ax)
    ax.set_title(f"Year Analysis of {title}'s top 10 similar titles")
    plt.show()
    
    if save==True:
        fileName = input()
        plt.savefig(fileName+'.png')

# %%
def function_genre_analysis(df, save=False, title=None):
    title = df.title.tolist()[0]
    count = defaultdict(int)
    for g in df.genre:
        for each in g.split(','):
            each = each.rstrip().lstrip()
            count[each] += 1
    genre_analysis = pd.DataFrame(data=[count])
    genre_analysis = genre_analysis.transpose().reset_index().rename(columns={'index':'genre',0:'count'})
    genre_analysis = genre_analysis.sort_values(by='count', ascending=False)

    fig, ax = plt.subplots(figsize=(10,6))
    sns.barplot(x='genre', y='count', data=genre_analysis)
    show_values_on_bars(ax)
    plt.title(f"Genre Analysis of {title}'s top 10 similar titles'")
    plt.show()
    
    if save==True:
        fileName = input()
        plt.savefig(fileName+'.png')

# %%
def imdb_analysis(df):
    
    idx = ['median', 'mean', 'max', 'min']
    cols = ['imdb_rating','imdb_votes']
    analysisDf = pd.DataFrame(index=idx, columns=cols)
    imdb = df.imdb_rating.tolist()
    imdb = [float(i) for i in imdb]
    rating_list = [np.median(imdb), np.mean(imdb), np.max(imdb), np.min(imdb)]
    rating_list = [round(k,2) for k in rating_list]
    
    votes = df.imdb_votes.tolist()
    votes = [int(j) for j in [count.replace(',','') for count in votes]]
    votes_list = [np.median(votes), np.mean(votes), np.max(votes), np.min(votes)]
    votes_list = [round(h) for h in votes_list]
    
    analysisDf['imdb_rating'] = rating_list
    analysisDf['imdb_votes'] = votes_list
    
    return analysisDf

# %%
# any originals in its 10 recommendations?
def check_originals(df, org):
    l = []
    for t in df.title:
        if t.lower() in org:
            l.append(t)
    return l

# %%
def pipeline(df, media_type='movie'):
    '''
    This function shows the year analysis, genre analyis, imdb analysis, and finally it checks if there is any Netflix Originals included.
    '''
    if media_type=='movie':
        function_year_analysis(df)
        function_genre_analysis(df)
        print(imdb_analysis(df))
        print(check_originals(df, orgMovie))
    else:
        year_analysis(df)
        genre_analysis(df)
        print(imdb_analysis(df))
        print(check_originals(df, orgTvshow))

# %% [markdown]
# # Youtube PIPELINE FUNCTIONS

# %%
def video_stats(list_of_titles):
    statsDf = pd.DataFrame(columns=['viewCount','likeCount','dislikeCount','favoriteCount','commentCount'])
    for title in list_of_titles:

        rq = youtube.videos().list(
                part="statistics",
                id=videoIds[title])
        rs = rq.execute()
        stats = rs['items'][0]['statistics']
        temp = pd.DataFrame(data=[stats], columns=['viewCount','likeCount','dislikeCount','favoriteCount','commentCount'], index=[title]).astype(int)
        statsDf = statsDf.append(temp)
    statsDf = statsDf.sort_values(by='viewCount', ascending=False)
    return statsDf

# %%
# test to retrieve 1000 comments
def get_1kcomments(videoId, preprocess=True):
    '''
    The function returns a list of 1000 comments.
    
    '''
    rq = youtube.commentThreads().list(
            part="snippet,replies",
            maxResults = 100,
            videoId=videoId)

    comments_list = list()
    nextPageToken = list()

    for i in range(10):
        if i == 0:
            try:
                rq = youtube.commentThreads().list(
                part="snippet,replies",
                maxResults = 100,
                videoId=videoId)
                rs = rq.execute()
                for i in range(100):
                    comments_list.append(rs['items'][i]['snippet']['topLevelComment']['snippet']['textOriginal'])

                nextPageToken.append(rs['nextPageToken'])
            except:
                continue
        else:
            try:
                rq = youtube.commentThreads().list(
                part="snippet,replies",
                maxResults = 100,
                videoId=videoId,
                pageToken=nextPageToken[i-1])
                rs = rq.execute()
                for i in range(100):
                    comments_list.append(rs['items'][i]['snippet']['topLevelComment']['snippet']['textOriginal'])

                nextPageToken.append(rs['nextPageToken'])
            except:
                continue
    if preprocess == True:    
        return [preprocess_text(comment) for comment in comments_list]
    else:
        return comments_list

# %%
def sentiment(preprocessed_comments):
    '''
    This function returns a dataframe consisting of polarity and subjectivity of the given movie reviews.
    '''
    polarity = list()
    subjectivity = list()
    for comment in preprocessed_comments:
        tb = TextBlob(comment)
        polarity.append(tb.sentiment[0])
        subjectivity.append(tb.sentiment[1])
    
    df = pd.DataFrame()
    df['polarity'] = polarity
    df['subjectivity'] = subjectivity
    return df

# %%
def create_wordcloud(preprocessed_comments, file_name='noID', max_font_size=150, max_words=100, background_color="white", save=False):
    all_comments = ','.join(preprocessed_comments).replace(',', ' ').replace('movie', ' ')
    wordcloud = WordCloud(max_font_size=max_font_size, max_words=max_words, background_color=background_color).generate(all_comments)
    wordcloud.to_file(file_name+'.png')
    plt.figure(figsize=(10,8))
    plt.imshow(wordcloud, interpolation='bilinear')
    plt.axis("off")
    if save==True:
        name=input()
        plt.savefig(name+'.png')
    plt.show()

# %%
def sentiment_counts(df, sep=0.1):
    '''
    This function returns a dataframe containing the value counts of sentiment
    '''
    sent = defaultdict(int)
    for v in df['polarity']:
        if v > sep:
            sent['positive'] += 1
        elif v < -sep:
            sent['negative'] += 1
        else:
            sent['neutral'] += 1
    tempdf = pd.DataFrame(data = [sent], columns=['positive','neutral','negative'])
    tempdf = tempdf.transpose().reset_index().rename(columns={'index':'sentiment',0:'count'})
    tempdf['percentage'] = tempdf['count'].apply(lambda x: x/tempdf['count'].sum())
    
    return tempdf

# %%
def show_sentiment_counts(df, save=False):
    fig, ax = plt.subplots(figsize=(10,6))

    raw_count = sns.barplot(x='sentiment', y='count', data=df, ax=ax)
#     percentage = sns.barplot(x='sentiment', y='percentage', data=df, ax=ax[1])
    show_values_on_bars(ax)
#     show_values_on_bars(ax[1], round_out=False)
    ax.set_title('Counts')
#     ax[1].set_title('Percentage')
    if save==True:
        name=input()
        plt.savefig(name+'.png')
    plt.show()

# %%
def plot_sentiments(df, save=False):
    plt.figure(figsize=(10,6))
    sns.scatterplot(x='polarity', y='subjectivity', data=df)
    if save==True:
        name=input()
        plt.savefig(name+'.png')
    plt.show()

# %%
def youtube_pipeline(ID):

        
    comments = get_1kcomments(ID)
    create_wordcloud(comments)
    sent = sentiment(comments)
    plot_sentiments(sent)
    sent_count = sentiment_counts(sent)
    show_sentiment_counts(sent_count)

# %% [markdown]
# # 整體分析 function

# %%
def count_genres(genre_list):
    """
    genre_list is pd sereis
    return a dataframe
    """
    genres_count = defaultdict(int)
    for movie in genre_list:
        for genre in movie.split(','):
            genres_count[genre] += 1
    df = pd.DataFrame(data=[genres_count])
    df = df.transpose().reset_index().rename(columns={'index':'genres',0:'counts'}).sort_values(by = 'counts', ascending=False).reset_index(drop=True)
    df['percentage'] = df['counts'].apply(lambda x: round(x/df.counts.sum(),2))
    return df

# %%
def trend_in_yearN(df ,genre , N):
    """
    return how many title's are in the given genre in the given year.
    """
    x = count_genres(df.loc[df['year']== N].genres.values.tolist())
    return x.set_index('genres').loc[genre].values.tolist()[0]

# %%
def ten_year_trend(df, genre, s=2010, e=2020):
    """
    default setting start with 2010 end with 2019 (10 years).
    return a dictionary
    """
    trend = defaultdict(int)
    for key in range(s, e):
        year = str(key)
        trend[key] = trend_in_yearN(df, genre, year)
    return trend

# %%
def create_trend_dataframe(df, cols):
    """
    df = from which df to produce ten_year_trend
    cols = list of genres you want to include
    """
    trend_df = pd.DataFrame()
    for genre in cols:
        temp = pd.DataFrame(data=[ten_year_trend(df, genre)]).transpose().rename(columns={0:genre})
        trend_df = pd.concat([trend_df, temp], axis=1)
    return trend_df

# %% [markdown]
# # 總體電影 (3770) 部 分析

# %%
movieDf = pd.read_csv('movieDf_Jul28.csv', usecols=['title','genres','year','type','originals','everything'])

# %%
mv_org = movieDf.loc[movieDf['originals']==1].copy()

mv_genres_count = count_genres(movieDf.genres.values.tolist())
mv_org_genres_count = count_genres(mv_org.genres.values.tolist())

mv_genres_count['percentage'] = mv_genres_count['counts'].apply(lambda x: round(x/mv_genres_count.counts.sum(),2))
mv_org_genres_count['percentage'] = mv_org_genres_count['counts'].apply(lambda x: round(x/mv_org_genres_count.counts.sum(),2))

# %%
fig, ax = plt.subplots(1,2,figsize=(20,6))

bar1 = sns.barplot(x = 'genres',
                  y = 'counts',
                  data = mv_genres_count,
                  ax = ax[0],
                  orient = 'v')
show_values_on_bars(bar1, h_v='v', space=0.3)
ax[0].set_title('The movie library', size=15)
ax[0].tick_params('x',labelrotation=90,labelsize=15)



bar2 = sns.barplot(x = 'genres',
                  y = 'counts',
                  data = mv_org_genres_count,
                  ax = ax[1],
                  orient = 'v')
show_values_on_bars(bar2, h_v='v', space=0.3)
ax[1].set_title('Netflix Originals (movie)', size=15)
ax[1].tick_params('x',labelrotation=90, labelsize=15)

# plt.rc('ytick', labelsize=12) 
fig.tight_layout()
plt.savefig('NetflixLibraryGenreDistribution.png')
plt.show()

# %%
plt.rc('ytick', labelsize=12)

# %%
fig, ax = plt.subplots(1,2,figsize=(20,6))
bar = sns.barplot(x = 'percentage',
                  y = 'genres',
                  data = mv_genres_count,
                  ax = ax[0],
                  orient = 'h')
show_values_on_bars(bar, h_v='h',space=0.005, round_out=False)
ax[0].set_title('The distribution of Netflix movies')

bar = sns.barplot(x = 'percentage',
                  y = 'genres',
                  data = mv_org_genres_count,
                  ax = ax[1],
                  orient = 'h')
show_values_on_bars(bar, h_v='h',space=0.005, round_out=False)
ax[1].set_title('The distribution of Netflix Originals movies')
# plt.savefig('NetflixLibraryGenreDistribution%.png')
plt.show()

# %%
comedy = ten_year_trend(movieDf, 'comedy')
drama = ten_year_trend(movieDf, 'drama')
action = ten_year_trend(movieDf, 'action-and-adventure')
standup = ten_year_trend(movieDf, 'stand-up-and-talk')
thriller = ten_year_trend(movieDf, 'thriller')
documentary = ten_year_trend(movieDf, 'documentary')
family = ten_year_trend(movieDf, 'family')

fig, ax = plt.subplots(figsize=(10,6))
cd = sns.lineplot(x = list(comedy.keys()), y = list(comedy.values()), marker = 'X', ax = ax, label='comedy')
dm = sns.lineplot(x = list(drama.keys()), y = list(drama.values()), marker = 'X', ax = ax, label='drama')
ac = sns.lineplot(x = list(action.keys()), y = list(action.values()), marker = 'X', ax = ax, label='action')
st = sns.lineplot(x = list(standup.keys()), y = list(standup.values()), marker = 'X', ax = ax, label='standup')
tl = sns.lineplot(x = list(thriller.keys()), y = list(thriller.values()), marker = 'X', ax = ax, label='thriller')
dc = sns.lineplot(x = list(documentary.keys()), y = list(documentary.values()), marker = 'X', ax = ax, label='documentary')
fm = sns.lineplot(x = list(family.keys()), y = list(family.values()), marker = 'X', ax = ax, label='family')

ax.set_title('10-year genre trend')
plt.savefig('10_yearGenreTrend.png')
plt.show()

# %%
cols = ['drama','comedy','action-and-adventure','thriller','romance',
        'mystery', 'documentary','crime','family','fantasy']
create_trend_dataframe(movieDf, cols)
# Out:
#       drama  comedy  action-and-adventure  thriller  romance  mystery  \
# 2010   43.0    37.0                  22.0      18.0     28.0     15.0
# 2011   52.0    45.0                  18.0      22.0     20.0     18.0
# 2012   58.0    56.0                  31.0      24.0     22.0     19.0
# 2013   55.0    52.0                  22.0      20.0     24.0     19.0
# 2014   84.0    81.0                  51.0      45.0     35.0     35.0
# 2015  144.0   106.0                  55.0      52.0     59.0     48.0
# 2016  213.0   147.0                  87.0     101.0     62.0     89.0
# 2017  271.0   227.0                 118.0     135.0     94.0    113.0
# 2018  242.0   196.0                 102.0     111.0     72.0     86.0
# 2019  180.0   167.0                  74.0      98.0     58.0     71.0
#
#       documentary  crime  family  fantasy
# 2010         10.0   10.0     9.0     15.0
# 2011         11.0   12.0    22.0     10.0
# 2012          8.0   15.0    13.0      6.0
# ...

# %%
c = 0
for y in movieDf.year:
    try:
        o = int(y)
        c+=1
    except:
        if y== 'No info':
            c+=1
            pass
        else:
            print(y)
            print(c)
            c+=1
# Out:
# rahe
# 571
# love
# 1025
# bomb
# 1773
# mack
# 2422
# luke
# 3114

# %%
d = defaultdict(int)
for y in movieDf.year:
    d[y] += 1

# %%
x = pd.DataFrame(data=[d])
x.drop(columns=['rahe','love','bomb','mack','luke'],inplace=True)
x = x.transpose().reset_index().rename(columns={'index':'year',0:'count'}).sort_values(by='year').reset_index(drop=True)
x = x.drop(index=68)

# %%
plt.figure(figsize=(10,6))
sns.barplot(x='year', y='count', data=x)
plt.xticks(rotation=90, size=9)
plt.title('The movie library', size=15)
plt.xlabel('year',size=15)
plt.ylabel('count',size=15)
plt.savefig('yearWholeLib.png')
plt.show()

# %%
n = pd.DataFrame(data = movieDf.originals.value_counts())
n = n.transpose().reset_index(drop=True).rename(columns={0:'Others', 1:'Netflix Originals'})
n = n.transpose().reset_index().rename(columns={'index':'type',0:'count'})

# %%
n['percentage'] = n['count'].apply(lambda x: round(x/n['count'].sum(),2))

# %%
fig, ax = plt.subplots(1,2,figsize=(20,6))

sns.barplot(x='type',y='count', data=n, ax=ax[0])

ax[0].set_title('The movie library (raw count)', size= 15)
ax[0].tick_params('both',labelsize=15)
ax[0].set_xlabel('', size=20)
ax[0].set_ylabel('', size=20)
show_values_on_bars(ax[0])

sns.barplot(x='type',y='percentage', data=n, ax=ax[1])
ax[1].set_title('The movie library (percentage)', size= 15)
ax[1].tick_params('both',labelsize=15)
ax[1].set_xlabel('', size=20)
ax[1].set_ylabel('', size=20)
show_values_on_bars(ax[1], round_out=False)


plt.tight_layout()
plt.savefig('NOmovieCounts.png')
plt.show()

# %% [markdown]
# ## Create Corpus and apply word embedding

# %%
adjust = "A grounded, soulful, celebratory comedy about three mothers and their adult sons. The film explores the stage after motherhood, Otherhood, when you have to redefine your relationship with your children, friends, spouse, and most importantly, yourself. comedy"
x = movieDf['everything'].tolist()
x[2292] = adjust
movieDf['everything'] = x
# movieDf.to_csv('movieDf_Jul28.csv')

# %%
adjust = "He promised supermodels and yachts, but delivered tents and cheese sandwiches. How one man engineered a music festival disaster. An exclusive behind the scenes look at the infamous unraveling of the Fyre music festival. documentary"
x = movieDf['everything'].tolist()
x[1131] = adjust
movieDf['everything'] = x
# movieDf.to_csv('movieDf_Jul28.csv')

# %%
# movieTkDocs = [tokenise(doc) for doc in movieDf.everything.values.tolist()] #tokenise 
# # mapping out the title and each description. so later on i can search 
# movieMap = dict(zip(movieDf['title'].str.lower().tolist(), movieTkDocs))
# # lower the title (easy for search)
movieTitleVec = vec_representation(movieDf)

# %% [markdown]
# ## top 10 movies analysis

# %%
top_10_movie = [
    'Bird Box',
    'Murder Mystery',
    'Triple Frontier',
    'The Perfect Date',
    'Tall Girl',
    'The Highwaymen',
    'Secret Obsession',
    'Always Be My Maybe',
    'Otherhood',
    'FYRE: The Greatest Party That Never Happened'
]

# %%
def top10SimMatrix(top10, titleVec, save=False):
    x = [i.lower() for i in top10]
    array = np.array([titleVec[title] for title in x])
    top10TvHeatMap = pd.DataFrame(columns=top10, index=top10, data = sklearn.metrics.pairwise.cosine_similarity(array))

    plt.figure(figsize=(10,6))
    sns.heatmap(top10TvHeatMap,annot=True, cbar=True, cmap='RdBu_r')
    xticks = [i for i in range(1, 11)]
    yticks = [i for i in range(1, 11)]
    plt.xticks(ticks=xticks)
    plt.yticks(ticks=yticks)
    
    
    if save==True:
        plt.savefig('top10SimMatrix.png')
    plt.show()

# %%
ticks = top_10_movie.copy()

# %%
x = [i.lower() for i in top_10_movie]
array = np.array([movieTitleVec[title] for title in x])
ticks = [i for i in range(1,11)]
top10TvHeatMap = pd.DataFrame(columns=ticks, index=ticks, data = sklearn.metrics.pairwise.cosine_similarity(array))

plt.figure(figsize=(10,6))
sns.heatmap(top10TvHeatMap,annot=True, cbar=True, cmap='RdBu_r')
plt.title('Top 10 movies pairwise similarity', size=20)
plt.savefig('top10SimMatrix.png')

plt.show()

# %%
Ids = ['o2AsIXSh2xo','5YEVQDr2f3Q','Fo3yRLLrXQA','Hld-7oBn3Rk','NfpXeLVzJIw','aH6vC-BBKOc','Nc6loZU3kjQ','iHBcWHY9lN4','q2b8MKsUloc','uZ0KNVU2fV0']
top10MovieVideoId = dict(zip(top_10_movie,Ids))

# %%
top10MovieStatsDf = pd.DataFrame(columns=['viewCount','likeCount','dislikeCount','favoriteCount','commentCount'])
for title in top_10_movie:

    rq = youtube.videos().list(
            part="statistics",
            id=top10MovieVideoId[title])
    rs = rq.execute()
    stats = rs['items'][0]['statistics']
    temp = pd.DataFrame(data=[stats], columns=['viewCount','likeCount','dislikeCount','favoriteCount','commentCount'], index=[title]).astype(int)
    top10MovieStatsDf = top10MovieStatsDf.append(temp)
top10MovieStatsDf = top10MovieStatsDf.sort_values(by='viewCount', ascending=False)

# %%
ratio = []
likes = top10MovieStatsDf.likeCount.tolist()
dislikes = top10MovieStatsDf.dislikeCount.tolist()
for i in range(10):
    ratio.append(likes[i]/(likes[i]+dislikes[i]))
ratio = [round(j,2) for j in ratio]

top10MovieStatsDf['ratio'] = ratio

# %%
top10MovieStatsDf
# Out:
#                                              viewCount likeCount dislikeCount  \
# Bird Box                                      22991561    182281         7921
# The Perfect Date                              13443123    373999         7898
# Murder Mystery                                10026213    149840         3605
# Triple Frontier                                6738348     47123         1279
# Tall Girl                                      5641802     97364        15972
# Always Be My Maybe                             4942059     96535         1376
# FYRE: The Greatest Party That Never Happened   4517620     21253         1210
# Secret Obsession                               4393933     68049         2044
# The Highwaymen                                 3467764     28600          513
# Otherhood                                      1361418     17858          562
#
#                                              favoriteCount commentCount  ratio
# ...

# %%
top10_titles = top_10_movie.copy()
top10_titles[9] = 'Fyre'
top10_year = [2019 for i in range(10)]
top10_year[0] = 2018

# %%
top10_omdb_results = pd.DataFrame()
for ix in range(10):
    try:
        top10_omdb_results = top10_omdb_results.append(omdb_get(top10_titles[ix],top10_year[ix],'movie'), ignore_index=True)
    except:
        print(ix)

# %%
top10_omdb_results[['title','imdb_rating','imdb_votes']]
# Out:
#                 title imdb_rating imdb_votes
# 0            Bird Box         6.6    264,054
# 1      Murder Mystery         6.0     92,839
# 2     Triple Frontier         6.4     99,471
# 3    The Perfect Date         5.8     29,153
# 4           Tall Girl         5.2     15,791
# 5      The Highwaymen         6.9     68,160
# 6    Secret Obsession         4.3     16,816
# 7  Always Be My Maybe         6.8     41,643
# 8           Otherhood         6.1      8,514
# 9                Fyre         7.2     34,032

# %%
top10MovieVideoId
# Out:
# {'Bird Box': 'o2AsIXSh2xo',
#  'Murder Mystery': '5YEVQDr2f3Q',
#  'Triple Frontier': 'Fo3yRLLrXQA',
#  'The Perfect Date': 'Hld-7oBn3Rk',
#  'Tall Girl': 'NfpXeLVzJIw',
#  'The Highwaymen': 'aH6vC-BBKOc',
#  'Secret Obsession': 'Nc6loZU3kjQ',
#  'Always Be My Maybe': 'iHBcWHY9lN4',
#  'Otherhood': 'q2b8MKsUloc',
#  'FYRE: The Greatest Party That Never Happened': 'uZ0KNVU2fV0'}

# %%
tallGirl_comments = get_1kcomments(top10MovieVideoId['Tall Girl'], preprocess=False)

# %%
tallGirl_comments_ppv2 = [preprocess_text_v2(comment) for comment in tallGirl_comments]

# %%
tallGirl_comments_ppv2
# Out:
# ['you think your life is hard try being tall i wear size 13 nikes mens size 13 nikespeople are dying jodie',
#  'those who are telling that whats wrong of being 61 then come to my country people will stare at you like you are an alien especially if you are a woman',
#  'savage come backs for girls who are tall1hows the wether up thereyou its great actually what about down there oh yeah its raining2 your as tall as the skyyou oh yeah its so im in a world where you dont exist3your hands are massiveyou yes its so i can pick you up and squish you4your so tall ewyou im not tall its just that your short please enjoy ',
#  'at least its better than being short im going into seventh grade and im 4 3 ',
#  'she should come to my school and then we will call her shorty',
#  'um if she just put her hair downshe could probably walk the runway',
#  'when are we getting short boy',
#  'tall is not that bad my sister is 6 foot and she is 11 she is the best basketball player',
# ...

# %%
create_wordcloud(tallGirl_comments_ppv2, save=True)
# Out:
#  tgV2

# %%
tallGirl_sent = sentiment(tallGirl_comments_ppv2)
tallGirl_sentCount = sentiment_counts(tallGirl_sent, sep=0.1)
show_sentiment_counts(tallGirl_sentCount)

# %%
test = TextBlob("its better then being a guy whos a sophomore and 52")
test2 = TextBlob("This movie is literally an incorrect depiction of the modern generation. It's pretty much what boomers assume teenagers act like.")
test3 = TextBlob("does she realise that in the netherlands average heights of an man in the netherlands is 6 foot do basicly we have plenty of men way taller than her")

# %%
print(test.sentiment)
print(test2.sentiment)
print(test3.sentiment)
# Out:
# Sentiment(polarity=0.5, subjectivity=0.5)
# Sentiment(polarity=0.21666666666666667, subjectivity=0.5)
# Sentiment(polarity=-0.075, subjectivity=0.26249999999999996)

# %% [markdown]
# # Try 5 Recommendations

# %%
fiveSim = pd.DataFrame()
for movie in top_10_movie:
    df = get_topN_similar(movie, movieTitleVec, movieDf, N=5)
    fiveSim = fiveSim.append(df, ignore_index=True)

# %%
t = fiveSim.title.tolist()
t[1] = 'the silence'
fiveSim['title'] = t

# %%
titles_for_omdb = fiveSim.title.tolist()
year_for_omdb = fiveSim.year.tolist()

year_for_omdb[39] = 2018
titles_for_omdb[50] = 'Ang tanging Ina'
titles_for_omdb[54] = 'Fyre'
titles_for_omdb[55] = "Who the Fuck Is That Guy? The Fabulous Journey of Michael Alago"
year_for_omdb[55] = 2017
titles_for_omdb[56] = 'Woodstock'
titles_for_omdb[59] = 'Panoramas'
year_for_omdb[59] = 2016

# %%
fiveSim_omdb = pd.DataFrame()
for ix in range(60):
    try:
        fiveSim_omdb = fiveSim_omdb.append(omdb_get(titles_for_omdb[ix],year_for_omdb[ix],'movie'), ignore_index=True)
    except:
        print(ix)

# %% [markdown]
# ## 5 Sim year graph

# %%
fiveSim_yearGraph = sorted(dict(fiveSim_omdb['year'].value_counts()).items(), key=lambda x: int(x[0]))

fiveSim_year_graph = pd.DataFrame(data=fiveSim_yearGraph)
fiveSim_year_graph.rename(columns={0:'year',1:'count'}, inplace=True)

# %%
fig, ax = plt.subplots(figsize=(10,6))
sns.barplot(x='year', y='count', data=fiveSim_year_graph)
show_values_on_bars(ax)
plt.title('The release year distribution top 10 Netflix Origianls and their recommendations', size=15)
plt.xticks(rotation=90)
plt.savefig('Top10MostWatchedMovieSimilarity_5sim.png')
plt.show()

# %%
# How many originals?
sim = fiveSim.title.tolist()
sim = [i for i in sim if i not in [l.lower() for l in top_10_movie]]
sim = [i for i in sim if search(i, movieDf).originals.tolist()[0]==1]    
sim.remove('love is blind')

# %%
sim
# Out:
# ['the silence',
#  'the forest of love',
#  'how it ends',
#  'the crew',
#  'extraction',
#  'how to get over a breakup',
#  "chris d'elia: man on fire"]

# %%
temp = pd.DataFrame(data=[{'Others':43,'Netflix Originals':7}])
temp  = temp.transpose().reset_index().rename(columns={'index':'type',0:'count'})

# %%
fig, ax = plt.subplots(figsize=(10,6))

sns.barplot(x='type',y='count', data=temp)

ax.set_title('The number of Netflix Originals (50 recommendations)', size= 15)
# ax.set_xlabel('type', size=20)
# ax.set_ylabel('count', size=20)
show_values_on_bars(ax)


plt.tight_layout()
plt.savefig('NO50rec.png')
plt.show()

# %%
mapping_for_mvCopies = defaultdict(str)
for i in range(10):
    if i != 9:
        mapping_for_mvCopies[f"mv0{str(i+1)}"] = top_10_movie[i]
    else:
        mapping_for_mvCopies["mv10"] = top_10_movie[i]

# %%
mv01 = fiveSim_omdb.iloc[0:6,:].copy()
mv02 = fiveSim_omdb.iloc[6:12,:].copy()
mv03 = fiveSim_omdb.iloc[12:18,:].copy()
mv04 = fiveSim_omdb.iloc[18:24,:].copy()
mv05 = fiveSim_omdb.iloc[24:30,:].copy()
mv06 = fiveSim_omdb.iloc[30:36,:].copy()
mv07 = fiveSim_omdb.iloc[36:42,:].copy()
mv08 = fiveSim_omdb.iloc[42:48,:].copy()
mv09 = fiveSim_omdb.iloc[48:54,:].copy()
mv10 = fiveSim_omdb.iloc[54:60,:].copy()

# some adjustments 
# rating_adj = mv08.imdb_rating.tolist()
# rating_adj[5] = 6.2
# rating_adj[9] = 6.4

# mv08['imdb_rating'] = rating_adj
# votes_adj = mv08.imdb_votes.tolist()
# votes_adj[5] = '1,545'
# votes_adj[9] = '11'
# mv08['imdb_votes'] = votes_adj

# %%
ranking = ['No.1','No.2','No.3','No.4','No.5','No.6','No.7','No.8','No.9','No.10']
count = [3,0,2,0,0,0,0,1,1,0]
x = pd.DataFrame()
x['Movie'] = ranking
x['Count'] = count

fig, ax = plt.subplots(figsize=(10,6))
sns.barplot(x='Movie',y='Count',data=x)
ax.set_title('The number of Netflix Originals within the recommendation list.', size=15)
show_values_on_bars(ax)
plt.savefig('xxx.png')
plt.show()

# %%
check_originals(mv09, sim)
# Out:
# ["Chris D'Elia: Man on Fire"]

# %%
mv09[['title','imdb_rating','imdb_votes']]
# Out:
#                         title imdb_rating imdb_votes
# 48                  Otherhood         6.1      8,514
# 49             Fun Mom Dinner         5.2      4,558
# 50            Ang tanging Ina         6.5        188
# 51  Chris D'Elia: Man on Fire         6.6      1,488
# 52                      Bratz         3.1     17,454
# 53             Mansfield Park         7.1     21,345

# %%
mv03[['title','imdb_rating','imdb_votes']].drop(index=[14,16,17])
# Out:
#               title imdb_rating imdb_votes
# 12  Triple Frontier         6.4     99,471
# 13         The Crew         6.3      3,873
# 15       Extraction         6.7    129,468

# %% [markdown]
# # Movie Subset – 10 Recommended Movies

# %%
top10_and_10sim = pd.DataFrame()
for movie in top_10_movie:
    df = get_topN_similar(movie, movieTitleVec, movieDf)
    top10_and_10sim = top10_and_10sim.append(df, ignore_index=True)

# %%
top10_and_10sim
# Out:
#                                           title  similarity  originals  \
# 0                                      bird box    1.000000          1
# 1                              the silence_2019    0.852333          0
# 2                                   dark places    0.845272          0
# 3                            the forest of love    0.837695          1
# 4                             the keeping hours    0.835456          0
# ..                                          ...         ...        ...
# 105       numero zero: the roots of italian rap    0.769773          0
# 106  my entire high school sinking into the sea    0.768069          0
# 107             maddman: the steve madden story    0.767983          0
# 108                                   studio 54    0.767654          0
# 109                                  supersonic    0.762865          0
#
#                                                            genres  year
# ...

# %%
# Only the silence_2019 has name issue. Handled it seperately.
t = top10_and_10sim.title.tolist()
t[1] = 'the silence'
top10_and_10sim['title'] = t

# %%
# top10_and_10sim.to_csv('similar.csv')

# %%
titles_for_omdb = top10_and_10sim.title.tolist()
year_for_omdb = top10_and_10sim.year.tolist()

# %% [markdown]
# ### Manually change incorrect information

# %%
# the old version of change
# year_for_omdb[29] = 2016
# titles_for_omdb[39] = '#TemanTapiMenikah'
# titles_for_omdb[67] = 'silent hill: revelation'
# year_for_omdb[85] = 2014
# titles_for_omdb[98] = 'the meyerowitz stories'
# titles_for_omdb[99] = 'fyre'
# titles_for_omdb[100] = 'theater of life'
# titles_for_omdb[102] = 'woodstock'
# titles_for_omdb[104] = 'Cézanne et moi'
# year_for_omdb[106] = 2017
# titles_for_omdb[108] = 'Todo sobre el asado'

# %%
year_for_omdb[29] = 2016
titles_for_omdb[39] = '#TemanTapiMenikah'
titles_for_omdb[74] = 'Tu hijo'
year_for_omdb[85] = 2014
titles_for_omdb[90] = "Ang tanging Ina"
titles_for_omdb[99] = 'Fyre'
titles_for_omdb[100] = "Who the Fuck Is That Guy? The Fabulous Journey of Michael Alago"
year_for_omdb[100] = 2017
titles_for_omdb[101] = 'woodstock'
titles_for_omdb[104] = 'Panoramas'
year_for_omdb[104] = 2016
titles_for_omdb[105] = 'Numero Zero: Alle origini del rap italiano'
year_for_omdb[107] = 2017
year_for_omdb[69] = 2018
year_for_omdb[8] = 2018

# %%
omdb_results = pd.DataFrame()
for ix in range(110):
    try:
        omdb_results = omdb_results.append(omdb_get(titles_for_omdb[ix],year_for_omdb[ix],'movie'), ignore_index=True)
    except:
        print(ix)

# %% [markdown]
# ## OMDB_RESULT年份分析

# %%
year_analysis = sorted(dict(omdb_results['year'].value_counts()).items(), key=lambda x: int(x[0]))

# %%
year_graph = pd.DataFrame(data=year_analysis)
year_graph.rename(columns={0:'year',1:'count'}, inplace=True)

# %%
# year_graph.rename(columns={0:'year',1:'count'}, inplace=True)
fig, ax = plt.subplots(figsize=(14,8))
sns.barplot(x='year', y='count', data=year_graph)
show_values_on_bars(ax)
plt.title('Top 10 Netflix Most Watched Movies and Their Recommendations Based on Similarity', size=20)
plt.xticks(rotation=90)
plt.savefig('Top10MostWatchedMovieSimilarity.png')
plt.show()

# %%
# How many originals?
sim = top10_and_10sim.title.tolist()
sim = [i for i in sim if i not in [l.lower() for l in top_10_movie]]

# %%
temp = pd.DataFrame(data=[{'Others':87,'Netflix Originals':17}])
temp  = temp.transpose().reset_index().rename(columns={'index':'type',0:'count'})

# %%
fig, ax = plt.subplots(figsize=(10,6))

sns.barplot(x='type',y='count', data=temp)

ax.set_title('The number of Netflix Originals (100 recommendations)', size= 20)
ax.set_xlabel('type', size=20)
ax.set_ylabel('count', size=20)
show_values_on_bars(ax)


plt.tight_layout()
plt.savefig('NO100rec.png')
plt.show()

# %%
t = defaultdict(int)
for i in top10_and_10sim.title:
    t[i] += 1
for k, v in t.items():
    if v != 1:
        print(k)

# %%
orgMovie = []
for mv in sim:
    if search(mv, movieDf).originals.values == 1:
        orgMovie.append(mv)

# %%
(orgMovie)
# Out:
# ['the silence',
#  'the forest of love',
#  'how it ends',
#  'mute',
#  'the crew',
#  'extraction',
#  'coin heist',
#  'the half of it',
#  'love is blind',
#  'extremely wicked, shockingly evil and vile',
#  'the warning',
#  'your son',
#  'how to get over a breakup',
#  "chris d'elia: man on fire",
#  'tig',
#  'how to get over a breakup',
#  'tom segura: ball hog']

# %% [markdown]
# 總共有17部電影是originals

# %%
mapping_for_mvCopies = defaultdict(str)
for i in range(10):
    if i != 9:
        mapping_for_mvCopies[f"mv0{str(i+1)}"] = top_10_movie[i]
    else:
        mapping_for_mvCopies["mv10"] = top_10_movie[i]

# %%
mv01 = omdb_results.iloc[0:11,:].copy()
mv02 = omdb_results.iloc[11:22,:].copy()
mv03 = omdb_results.iloc[22:33,:].copy()
mv04 = omdb_results.iloc[33:44,:].copy()
mv05 = omdb_results.iloc[44:55,:].copy()
mv06 = omdb_results.iloc[55:66,:].copy()
mv07 = omdb_results.iloc[66:77,:].copy()
mv08 = omdb_results.iloc[77:88,:].copy()
mv09 = omdb_results.iloc[88:99,:].copy()
mv10 = omdb_results.iloc[99:110,:].copy()

# some adjustments 
rating_adj = mv08.imdb_rating.tolist()
rating_adj[5] = 6.2
rating_adj[9] = 6.4

mv08['imdb_rating'] = rating_adj
votes_adj = mv08.imdb_votes.tolist()
votes_adj[5] = '1,545'
votes_adj[9] = '11'
mv08['imdb_votes'] = votes_adj

# %%
print(check_originals(mv09,orgMovie ))
# Out:
# ["Chris D'Elia: Man on Fire", 'Tig', 'How to Get Over a Breakup', 'Tom Segura: Ball Hog']

# %%
print(check_originals(mv01,orgMovie ))
print(check_originals(mv03,orgMovie ))
print(check_originals(mv09,orgMovie ))

# %%
mv01OrgAnalysis = mv01.loc[mv01.title.isin(['Bird Box','The Silence','The Forest of Love','How It Ends','Mute'])][['title','plot','imdb_rating','imdb_votes','genre']].copy()
mv03OrgAnalysis = mv03.loc[mv03.title.isin(['Triple Frontier','The Crew', 'Extraction', 'Coin Heist'])][['title','plot','imdb_rating','imdb_votes','genre']].copy()
mv09OrgAnalysis = mv09.loc[mv09.title.isin(['Otherhood',"Chris D'Elia: Man on Fire", 'Tig', 'How to Get Over a Breakup', 'Tom Segura: Ball Hog'])][['title','plot','imdb_rating','imdb_votes','genre']].copy()

# %%
def imdb_analysis(df):
    
    idx = ['median', 'mean', 'max', 'min']
    cols = ['imdb_rating','imdb_votes']
    analysisDf = pd.DataFrame(index=idx, columns=cols)
    imdb = df.imdb_rating.tolist()
    imdb_list = []
    for i in imdb:
        try:
            imdb_list.append(float(i))
        except:
            pass
#     imdb = [float(i) for i in imdb]
    rating_list = [np.median(imdb_list), np.mean(imdb_list), np.max(imdb_list), np.min(imdb_list)]
    rating_list = [round(k,2) for k in rating_list]
    
    votes = df.imdb_votes.tolist()
    votes_preprocess = []
    for j in [count.replace(',','') for count in votes]:
        if j == 'N/A':
            pass
        else:
            votes_preprocess.append(int(j))
#     votes = [int(j) for j in [count.replace(',','') for count in votes]]
    votes_list = [np.median(votes_preprocess), np.mean(votes_preprocess), np.max(votes_preprocess), np.min(votes_preprocess)]
    votes_list = [round(h) for h in votes_list]
    
    analysisDf['imdb_rating'] = rating_list
    analysisDf['imdb_votes'] = votes_list
    
    return analysisDf

# %%
ranking = ['No.1','No.2','No.3','No.4','No.5','No.6','No.7','No.8','No.9','No.10']
count = [4,0,3,1,1,2,1,1,4,0]
x = pd.DataFrame()
x['Movie'] = ranking
x['Count'] = count

fig, ax = plt.subplots(figsize=(10,6))
sns.barplot(x='Movie',y='Count',data=x)
ax.set_title('The number of Netflix Originals within the recommendation.', size=20)
show_values_on_bars(ax)
plt.savefig('xxx.png')
plt.show()

# %% [markdown]
# # Make the pipline all in one figure

# %%
def year_genre_analysis(df, save=False):
    fig, ax = plt.subplots(1,2, figsize=(20,6))

    title = df.title.tolist()[0]
    year = pd.DataFrame()
    year['year'] = df.year.value_counts().index.tolist()
    year['count'] = df.year.value_counts().tolist()
    year = year.astype(int).sort_values(by='year')
    
    year_ans = sns.barplot(x='year', y='count', data=year, ax=ax[0])
    show_values_on_bars(ax[0])
    ax[0].set_title(f"Year Analysis of {title}'s top 10 similar titles", size=20)
    ax[0].set_xlabel('Year', size=15)
    ax[0].set_ylabel('Count', size=15)

    count = defaultdict(int)
    for g in df.genre:
        for each in g.split(','):
            each = each.rstrip().lstrip()
            count[each] += 1
    genre_analysis = pd.DataFrame(data=[count])
    genre_analysis = genre_analysis.transpose().reset_index().rename(columns={'index':'genre',0:'count'})
    genre_analysis = genre_analysis.sort_values(by='count', ascending=False)

    genre_ans = sns.barplot(x='genre', y='count', data=genre_analysis, ax=ax[1])
    show_values_on_bars(ax[1])
    ax[1].set_title(f"Genre Analysis of {title}'s top 10 similar titles'", size=20)
    ax[1].set_xlabel('Genre', size=15)
    ax[1].set_ylabel('Count', size=15)
    
    plt.tight_layout()
    
    if save==True:
        fileName = input()
        plt.savefig(fileName+'.png')

    plt.show()

# %%
year_genre_analysis(mv01)

# %% [markdown]
# ## YouTube Analysis
# There are 4 movies are originals.
# Go to Netflix channel to grab videoID

# %%
# a mapping for video ID
videoIds = {
    'bird box':'o2AsIXSh2xo',
    'the silence': 'Y-ufZuqTd5c',
    'the forest of love':'ybsrYkz0V0A',
    'how it ends':'WJyyJ7lexnM',
    'mute':'ma8te7ywEio',
    'triple frontier':'Fo3yRLLrXQA',
    'extraction':'L6P3nI6VnlY',
    'coin heist':'xUyTRSlmXf4'
}

# %%
request = youtube.commentThreads().list(
        part="snippet,replies",
        maxResults = 100,
        videoId=videoIds['the silence'])

# %%
response = request.execute()

# %% [markdown]
# # TVshow

# %%
tvshowDf = pd.read_csv('tvshow_dataset_jul25.csv', usecols=['title','genres','year','originals','everything'])

# %%
tvshowDf.originals.value_counts()
# Out:
# 0    1268
# 1     792
# Name: originals, dtype: int64

# %%
tv_org = tvshowDf.loc[tvshowDf['originals']==1].copy()

tv_genres_count = count_genres(tvshowDf.genres.values.tolist())
tv_org_genres_count = count_genres(tv_org.genres.values.tolist())

tv_genres_count['percentage'] = tv_genres_count['counts'].apply(lambda x: round(x/tv_genres_count.counts.sum(),2))
tv_org_genres_count['percentage'] = tv_org_genres_count['counts'].apply(lambda x: round(x/tv_org_genres_count.counts.sum(),2))

# %%
fig, ax = plt.subplots(1,2,figsize=(20,6))
bar = sns.barplot(x = 'genres',
                  y = 'counts',
                  data = tv_genres_count,
                  ax = ax[0],
                  orient = 'v')
show_values_on_bars(bar, h_v='v', space=0.3)
ax[0].set_title('The TV show library',size=15)
ax[0].tick_params('x', labelrotation=90,labelsize=15)

bar = sns.barplot(x = 'genres',
                  y = 'counts',
                  data = tv_org_genres_count,
                  ax = ax[1],
                  orient = 'v')
show_values_on_bars(bar, h_v='v', space=0.3)
ax[1].set_title('Netflix Originals (TV show)', size=15)
ax[1].tick_params('x', labelrotation=90,labelsize=15)

plt.tight_layout()
plt.savefig('NetflixLibraryGenreDistributionTvshow.png')
plt.show()

# %%
ntv = pd.DataFrame(data = tvshowDf.originals.value_counts())
ntv = ntv.transpose().reset_index(drop=True).rename(columns={0:'Others', 1:'Netflix Originals'})
ntv = ntv.transpose().reset_index().rename(columns={'index':'type',0:'count'})

# %%
ntv['percentage'] = ntv['count'].apply(lambda x: round(x/ntv['count'].sum(),2))

# %%
fig, ax = plt.subplots(1,2,figsize=(20,6))

sns.barplot(x='type',y='count', data=ntv, ax=ax[0])

ax[0].set_title('The TV show library (raw count)', size= 15)
ax[0].tick_params('both',labelsize=15)
ax[0].set_xlabel('', size=20)
ax[0].set_ylabel('', size=20)
show_values_on_bars(ax[0])

sns.barplot(x='type',y='percentage', data=ntv, ax=ax[1])
ax[1].set_title('The TV show library (percentage)', size= 15)
ax[1].tick_params('both',labelsize=15)
ax[1].set_xlabel('', size=20)
ax[1].set_ylabel('', size=20)
show_values_on_bars(ax[1], round_out=False)


plt.tight_layout()
plt.savefig('NOmovieCountsTV.png')
plt.show()

# %%
comedy_mv = ten_year_trend(movieDf, 'comedy')
drama_mv = ten_year_trend(movieDf, 'drama')
action_mv = ten_year_trend(movieDf, 'action-and-adventure')
standup_mv = ten_year_trend(movieDf, 'stand-up-and-talk')
thriller_mv = ten_year_trend(movieDf, 'thriller')
documentary_mv = ten_year_trend(movieDf, 'documentary')
romance_mv = ten_year_trend(movieDf, 'romance')

fig, ax = plt.subplots(1,2,figsize=(20,6))
dm_mv = sns.lineplot(x = list(drama_mv.keys()), y = list(drama_mv.values()), marker = 'X', ax = ax[0], label='drama')
cd_mv = sns.lineplot(x = list(comedy_mv.keys()), y = list(comedy_mv.values()), marker = 'X', ax = ax[0], label='comedy')
ac_mv = sns.lineplot(x = list(action_mv.keys()), y = list(action_mv.values()), marker = 'X', ax = ax[0], label='action')
tl_mv = sns.lineplot(x = list(thriller_mv.keys()), y = list(thriller_mv.values()), marker = 'X', ax = ax[0], label='thriller')
rm_mv = sns.lineplot(x = list(romance_mv.keys()), y = list(romance_mv.values()), marker = 'X', ax = ax[0], label='romance')
dc_mv = sns.lineplot(x = list(documentary_mv.keys()), y = list(documentary_mv.values()), marker = 'X', ax = ax[0], label='documentary')
st_mv = sns.lineplot(x = list(standup_mv.keys()), y = list(standup_mv.values()), marker = 'X', ax = ax[0], label='standup')
ax[0].set_title('The movie library', size=15)
ax[0].tick_params('both',labelsize=15)

comedy = ten_year_trend(tvshowDf, 'comedy')
drama = ten_year_trend(tvshowDf, 'drama')
action = ten_year_trend(tvshowDf, 'action-and-adventure')
crime = ten_year_trend(tvshowDf, 'crime')
animation = ten_year_trend(tvshowDf, 'animation')
documentary = ten_year_trend(tvshowDf, 'documentary')
fantasy = ten_year_trend(tvshowDf, 'fantasy')

dm = sns.lineplot(x = list(drama.keys()), y = list(drama.values()), marker = 'X', ax = ax[1], label='drama')
cd = sns.lineplot(x = list(comedy.keys()), y = list(comedy.values()), marker = 'X', ax = ax[1], label='comedy')
ac = sns.lineplot(x = list(action.keys()), y = list(action.values()), marker = 'X', ax = ax[1], label='action')
dc = sns.lineplot(x = list(documentary.keys()), y = list(documentary.values()), marker = 'X', ax = ax[1], label='documentary')
cm = sns.lineplot(x = list(crime.keys()), y = list(crime.values()), marker = 'X', ax = ax[1], label='crime')
an = sns.lineplot(x = list(animation.keys()), y = list(animation.values()), marker = 'X', ax = ax[1], label='animation')
fs = sns.lineplot(x = list(fantasy.keys()), y = list(fantasy.values()), marker = 'X', ax = ax[1], label='fantasy')

ax[1].set_title('The TV show library', size=15)
ax[1].tick_params('both',labelsize=15)
plt.savefig('10_yearGenreTrend_mv&tv.png')
plt.show()

# %%
c = 0
for y in tvshowDf.year:
    try:
        o = int(y)
        c+=1
    except:
        if y== 'No info':
            c+=1
            pass
        else:
            print(y)
            print(c)
            c+=1
# Out:
# wild
# 131
# girl
# 813
# suni
# 820
# wolf
# 1050
# show
# 1151
# trip
# 1216
# dion
# 1280
# code
# 1294
# rome
# 1380
# soon
# 1501
# rome
# 1504
# rush
# 1505
# rasa
# 1528
# lady
# 1691
# love
# 1827
# mike
# 1882
# city
# 1887
# love
# 1982

# %%
d = defaultdict(int)
for y in tvshowDf.year:
    d[y] += 1

# %%
x = pd.DataFrame(data=[d])
x.drop(columns=['wild','girl','suni','wolf','show','trip','dion','code','rome','soon','rome','rush','rasa','lady','love','mike','city','love'],inplace=True)
x = x.transpose().reset_index().rename(columns={'index':'year',0:'count'}).sort_values(by='year').reset_index(drop=True)
x = x.drop(index=45)

# %%
plt.figure(figsize=(10,6))
sns.barplot(x='year', y='count', data=x)
plt.xticks(rotation=90, size=8)
plt.title('The TV show library', size=15)
plt.xlabel('year',size=15)
plt.ylabel('count',size=15)
plt.savefig('yearWholeLibTV.png')
plt.show()

# %% [markdown]
# # Tv show top 10 analysis

# %%
tvshowTitleVec = vec_representation(tvshowDf)

# %%
top10_tvshow = [
    'Stranger Things',
    'The Umbrella Academy',
    'Money Heist',
    'You',
    'Sex Education',
    'Our Planet',
    'Unbelievable',
    'Dead to Me',
    'When They See Us',
    'Elite'
]

# %%
def top10SimMatrix(top10, titleVec, save=False):
    x = [i.lower() for i in top10]
    array = np.array([titleVec[title] for title in x])
    top10TvHeatMap = pd.DataFrame(columns=top10, index=top10, data = sklearn.metrics.pairwise.cosine_similarity(array))

    plt.figure(figsize=(10,6))
    sns.heatmap(top10TvHeatMap,annot=True, cbar=True, cmap='RdBu_r')
    xticks = [i for i in range(1, 11)]
    yticks = [i for i in range(1, 11)]
    plt.xticks(ticks=xticks)
    plt.yticks(ticks=yticks)
    
    
    if save==True:
        plt.savefig('top10SimMatrix.png')
    plt.show()

# %%
x = [i.lower() for i in top10_tvshow]
array = np.array([tvshowTitleVec[title] for title in x])
ticks = [i for i in range(1,11)]
top10TvHeatMap = pd.DataFrame(columns=ticks, index=ticks, data = sklearn.metrics.pairwise.cosine_similarity(array))

plt.figure(figsize=(10,6))
sns.heatmap(top10TvHeatMap,annot=True, cbar=True, cmap='RdBu_r')
plt.title('TV show', size=15)
plt.savefig('top10SimMatrix_tv.png')
plt.show()

# %%
# stranger things 3 doesnt have official trailer on netflix channel. the closest is the official s1 s2 recap
# sex education s1 doesnt have trailer at all. I used Sex Education | Who's Who | Netflix
# when they see us s1 only teaser 

TvIds = ['JpbWqiUy0YM','0DAmWHxeoKw','TFJwUwnShnA','ga1m0wjzscU','NacdU20UM1o','aETNYyrqNYE','QTIkUzkbzQk','BwYBw1raC2o','YyoSErErnCE','QNwhAdrdwp0']
top10TvVideoId = dict(zip(top10_tvshow,TvIds))

# %%
top10TvStatsDf = pd.DataFrame(columns=['viewCount','likeCount','dislikeCount','favoriteCount','commentCount'])
for title in top10_tvshow:

    rq = youtube.videos().list(
            part="statistics",
            id=top10TvVideoId[title])
    rs = rq.execute()
    stats = rs['items'][0]['statistics']
    temp = pd.DataFrame(data=[stats], columns=['viewCount','likeCount','dislikeCount','favoriteCount','commentCount'], index=[title]).astype(int)
    top10TvStatsDf = top10TvStatsDf.append(temp)
top10TvStatsDf = top10TvStatsDf.sort_values(by='viewCount', ascending=False)

# %%
ratio = []
likes = top10TvStatsDf.likeCount.tolist()
dislikes = top10TvStatsDf.dislikeCount.tolist()
for i in range(10):
    ratio.append(likes[i]/(likes[i]+dislikes[i]))
ratio = [round(j,2) for j in ratio]

top10TvStatsDf['ratio'] = ratio

# %%
top10TvStatsDf
# Out:
#                      viewCount likeCount dislikeCount favoriteCount  \
# Stranger Things       11294506    300201         3143             0
# Elite                  9108742    111113         2597             0
# The Umbrella Academy   8148895    132503         2801             0
# Money Heist            6791906    112049         1684             0
# Unbelievable           4663137     62134         1080             0
# Dead to Me             2683264     24853          665             0
# You                    2006821     17809          361             0
# Our Planet             1961235     42244          302             0
# When They See Us        539097     10796          258             0
# Sex Education           373250     11222          242             0
#
#                      commentCount  ratio
# Stranger Things             18696   0.99
# Elite                        6819   0.98
# The Umbrella Academy         9383   0.98
# Money Heist                  8317   0.99
# ...

# %%
top10TvTitles = top10_tvshow.copy()
# top10_titles[9] = 'Fyre'
top10TvYear = [2019 for i in range(10)]
top10TvYear[0] = 2016
top10TvYear[2] = 2017
top10TvYear[3] = 2018
top10TvYear[9] = 2018

# %%
top10Tv_omdb_results = pd.DataFrame()
for ix in range(10):
    try:
        top10Tv_omdb_results = top10Tv_omdb_results.append(omdb_get(top10TvTitles[ix],top10TvYear[ix],'series'), ignore_index=True)
    except:
        print(ix)

# %%
top10Tv_omdb_results[['title','imdb_rating','imdb_votes']]

# %% [markdown]
# # Make Youtube analysis on Our Planet

# %%
planetComments = get_1kcomments(top10TvVideoId['Our Planet'], preprocess=False)
planetCommentsPp = [preprocess_text_v2(comment) for comment in planetComments]
planetSent = sentiment(planetCommentsPp)
planetSentCount = sentiment_counts(planetSent, sep=0.1)

# %%
planetComments
# Out:
# ['love it',
#  '301 dislikes :C',
#  'can anyone tell me the song played early in the video??',
#  "When ever i feel depressed i watch this type of documentaries and i get alive but Sade's thing is very few people watch this type of documentaries   they just containg garbase in their mind",
#  'That bird got some moves like charli damelio who ? 0:02',
#  'This should be made mandatory to watch in every school/ universities.',
#  'I  like   it',
#  'woooooow!! what a documentary it was. Loved every part and second of it. How spectacular and majestic mother nature is and the innumerable animals and species they call it "HOME". Makes me so dejected that we have exploited her so long for our petty and vested interests. High time to retrospect and introspect at an individual level of our choices and options before this catastrophe is irreversible and we reach a point of no return.',
#  'yo mate we need to save the planet',
# ...

# %%
create_wordcloud(planetCommentsPp, save=True)
# Out:
#  planetWordcloud

# %%
show_sentiment_counts(planetSentCount, save=True)
# Out:
#  planetSentCount

# %%
for series in top10_tvshow:
    comments = get_1kcomments(top10TvVideoId[series], preprocess=False)
    comments_pp = [preprocess_text_v2(comment) for comment in comments]
    create_wordcloud(comments_pp)

# %%
for series in top10_tvshow:
    comments = get_1kcomments(top10TvVideoId[series], preprocess=False)
    comments_pp = [preprocess_text_v2(comment) for comment in comments]
    sent = sentiment(comments_pp)
    sentCount = sentiment_counts(sent, sep=0.1)
    show_sentiment_counts(sentCount)

# %%
search('stranger things', tvshowDf)
# Out:
#                 title  \
# 1494  Stranger Things
#
#                                                                           genres  \
# 1494  drama,fantasy,horror,mystery,science-fiction,thriller,action-and-adventure
#
#       year  originals  \
# 1494  2016          1
#
#                                                                                                                                                                                                                             everything
# 1494  When a young boy vanishes, a small town uncovers a mystery involving secret experiments, terrifying supernatural forces, and one strange little girl. drama,fantasy,horror,mystery,science-fiction,thriller,action-and-adventure

# %%
search('the umbrella academy',tvshowDf)
# Out:
#                      title  \
# 1805  The Umbrella Academy
#
#                                                                        genres  \
# 1805  action-and-adventure,lgbtq,comedy,drama,fantasy,science-fiction,mystery
#
#       year  originals  \
# 1805  2019          1
#
#                                                                                                                                                                                                              everything
# 1805  A dysfunctional family of superheroes comes together to solve the mystery of their father's death, the threat of the apocalypse and more. action-and-adventure,lgbtq,comedy,drama,fantasy,science-fiction,mystery

# %%
search('You',tvshowDf)
# Out:
#      title                        genres  year  originals  \
# 2038   YOU  crime,drama,romance,thriller  2018          1
#
#                                                                                                                                                                                                                                                                                                                                               everything
# 2038  When a brilliant bookstore manager crosses paths with an aspiring writer, he uses the internet and social media to gather the most intimate of details and get close to her. A charming and awkward crush quickly becomes obsession as he quietly and strategically removes every obstacle - and person - in his way. crime,drama,romance,thriller

# %%
search('dead to me', tvshowDf)
# Out:
#           title                      genres  year  originals  \
# 402  Dead to Me  comedy,drama,mystery,crime  2019          1
#
#                                                                                                                                                                        everything
# 402  A hotheaded widow searching for the hit-and-run driver who mowed down her husband befriends an eccentric optimist who isn't quite what she seems. comedy,drama,mystery,crime

# %% [markdown]
# # Tv show 5 recommendations

# %%
top10_tvshow = [
    'Stranger Things',
    'The Umbrella Academy',
    'Money Heist',
    'You',
    'Sex Education',
    'Our Planet',
    'Unbelievable',
    'Dead to Me',
    'When They See Us',
    'Elite'
]

# %%
fiveSim_tv = pd.DataFrame()
for tvshow in top10_tvshow:
    df = get_topN_similar(tvshow, tvshowTitleVec, tvshowDf,N=5)
    fiveSim_tv = fiveSim_tv.append(df, ignore_index=True)

# %%
fiveSim_tv.loc[~fiveSim_tv.index.isin([0,6,12,18,24,30,36,42,48,54])].loc[fiveSim_tv.originals==1]
# Out:
#                                       title  similarity  originals  \
# 1                               creeped out    0.893401          1
# 2                                 the order    0.878219          1
# 3                      the umbrella academy    0.877068          1
# 4                             kiss me first    0.868795          1
# 7                           stranger things    0.877068          1
# 8                                  daybreak    0.868690          1
# 9                            mob psycho 100    0.868291          1
# 11                             black summer    0.864233          1
# 15                           green frontier    0.865966          1
# 16                                 ad vitam    0.864223          1
# 17                          when heroes fly    0.860076          1
# 20                               love alarm    0.854455          1
# 26                                 trinkets    0.788005          1
# ...

# %%
tv01 = fiveSim_tv.iloc[0:6,:].copy()
tv02 = fiveSim_tv.iloc[6:12,:].copy()
tv03 = fiveSim_tv.iloc[12:18,:].copy()
tv04 = fiveSim_tv.iloc[18:24,:].copy()
tv05 = fiveSim_tv.iloc[24:30,:].copy()
tv06 = fiveSim_tv.iloc[30:36,:].copy()
tv07 = fiveSim_tv.iloc[36:42,:].copy()
tv08 = fiveSim_tv.iloc[42:48,:].copy()
tv09 = fiveSim_tv.iloc[48:54,:].copy()
tv10 = fiveSim_tv.iloc[54:60,:].copy()

# %%
check_originals(tv01)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-355-2c3a633b15da> in <module>
# ----> 1 check_originals()
#
# TypeError: check_originals() missing 2 required positional arguments: 'df' and 'org'

# %%
orgTvshow_index = fiveSim_tv.loc[fiveSim_tv.originals==1].index.tolist()
# for i in [0,11,22,33,44,55,66,77,88,99]:
#     orgTvshow_index.remove(i)
orgTvshow = [fiveSim_tv.iloc[ix,0] for ix in orgTvshow_index]

# %%
# orgTvshow = []
# for ix in orgTvshow_index:
#     orgTvshow.append(fiveSim_tv.iloc[ix,0] for )

# %% [markdown]
# # Get OMDb Results

# %%
tvshow10sim_titles = tvshow_10sim.title.tolist()
tvshow10sim_year = tvshow_10sim.year.tolist()

# %%
# Manuually adjust
tvshow10sim_titles[28] = 'El Cartel de los Sapos'
tvshow10sim_titles[50] = 'cloudy with a chance of meatballs'
tvshow10sim_titles[60] = 'chasing monsters'
tvshow10sim_titles[93] = 'jessica jones'
tvshow10sim_titles[91] = 'vis a vis'
tvshow10sim_titles[104] = 'Retribution'
tvshow10sim_titles[108] = 'vis a vis'

tvshow10sim_year[35] = 2019
tvshow10sim_year[57] = 2014
tvshow10sim_year[60] = 2015

# %%
tvshow_omdb_results = pd.DataFrame()
for ix in range(110):
    try:
        tvshow_omdb_results = tvshow_omdb_results.append(omdb_get(tvshow10sim_titles[ix],tvshow10sim_year[ix], media_type='series'), ignore_index=True)
    except:
        print(ix)

# %%
tvshow_omdb_results.columns

# %% [markdown]
# ## OMDB_RESULT年份分析 TVSHOW

# %%
# 修改 year 的格式
tvshow_start_year = [tvshow_omdb_results['year'].tolist()[ix].split('–')[0] for ix in range(110)]
tvshow_start_year = [int(y) for y in tvshow_start_year]

# %%
tvshow_omdb_results['year'] = tvshow_start_year

# %%
tvshow_year_analysis = sorted(dict(tvshow_omdb_results['year'].value_counts()).items(), key=lambda x: int(x[0]))

# %%
tvshow_year_graph = pd.DataFrame(data=tvshow_year_analysis)
# tvshow_year_graph.rename(columns={0:'year',1:'count'}, inplace=True)

# %%
# year_graph.rename(columns={0:'year',1:'count'}, inplace=True)
fig, ax = plt.subplots(figsize=(14,8))
sns.barplot(x='year', y='count', data=tvshow_year_graph)
show_values_on_bars(ax)
plt.title('Top 10 Netflix Most Watched Tvshows and Their Recommendations Based on Similarity')
plt.show()

# %%
org_number = len(orgTvshow)
print(f"There are {org_number} series are produced by Netflix Originals.")
# Out:
# There are 45 series are produced by Netflix Originals.

# %%
mapping_for_tvshowCopies = defaultdict(str)
for i in range(10):
    if i != 9:
        mapping_for_tvshowCopies[f"tv0{str(i+1)}"] = top10_tvshow[i]
    else:
        mapping_for_tvshowCopies["tv10"] = top10_tvshow[i]

# %%
mapping_for_tvshowCopies
# Out:
# defaultdict(str,
#             {'tv01': 'Stranger Things',
#              'tv02': 'The Umbrella Academy',
#              'tv03': 'Money Heist',
#              'tv04': 'You',
#              'tv05': 'Sex Education',
#              'tv06': 'Our Planet',
#              'tv07': 'Unbelievable',
#              'tv08': 'Dead to Me',
#              'tv09': 'When They See Us',
#              'tv10': 'Elite'})

# %%
tv01 = tvshow_omdb_results.iloc[0:11,:].copy()
tv02 = tvshow_omdb_results.iloc[11:22,:].copy()
tv03 = tvshow_omdb_results.iloc[22:33,:].copy()
tv04 = tvshow_omdb_results.iloc[33:44,:].copy()
tv05 = tvshow_omdb_results.iloc[44:55,:].copy()
tv06 = tvshow_omdb_results.iloc[55:66,:].copy()
tv07 = tvshow_omdb_results.iloc[66:77,:].copy()
tv08 = tvshow_omdb_results.iloc[77:88,:].copy()
tv09 = tvshow_omdb_results.iloc[88:99,:].copy()
tv10 = tvshow_omdb_results.iloc[99:110,:].copy()

# %%
pipeline(tv08, media_type='series')
# Out:
#         imdb_rating  imdb_votes
# median         7.70       24603
# mean           7.67       48593
# max            8.60      203768
# min            7.00          20
# ['The End of the F***ing World', 'Lady Dynamite']

# %%
mapping_for_tvshowCopies
# Out:
# defaultdict(str,
#             {'tv01': 'Stranger Things',
#              'tv02': 'The Umbrella Academy',
#              'tv03': 'Money Heist',
#              'tv04': 'You',
#              'tv05': 'Sex Education',
#              'tv06': 'Our Planet',
#              'tv07': 'Unbelievable',
#              'tv08': 'Dead to Me',
#              'tv09': 'When They See Us',
#              'tv10': 'Elite'})

# %%
np.mean(tvshow_omdb_results.imdb_rating.astype(float))
# Out:
# 7.4409090909090905

# %%
top10_omdbResults = tvshow_omdb_results.loc[tvshow_omdb_results['title'].isin(top10_tvshow)].drop_duplicates(subset='title').copy()

# %%
top10_imdb_analysis = top10_omdbResults[['title','imdb_rating','imdb_votes']].set_index('title')

# %%
top10_imdb_analysis
# Out:
#                      imdb_rating imdb_votes
# title
# Stranger Things              8.8    751,886
# The Umbrella Academy         7.9    102,539
# Money Heist                  8.4    256,285
# You                          7.8    125,151
# Sex Education                8.3    137,145
# Our Planet                   9.3     26,892
# Unbelievable                 8.4     60,493
# Dead to Me                   8.1     45,793
# When They See Us             8.9     78,556
# Elite                        7.6     39,316

# %%
len(set(orgTvshow))
# Out:
# 37

# %%
pipeline(tv01, media_type='sereis')
# Out:
#         imdb_rating  imdb_votes
# median         6.90       13627
# mean           7.16      134812
# max            9.00      751886
# min            5.10         346
# ['Stranger Things', 'Creeped Out', 'The Order', 'The Umbrella Academy', 'Kiss Me First', 'Diablero', 'Curon', 'Mob Psycho 100']

# %%
# top10 tvshow themselves how are the similarity between them

# %%
top10_tvshow
# Out:
# ['Stranger Things',
#  'The Umbrella Academy',
#  'Money Heist',
#  'You',
#  'Sex Education',
#  'Our Planet',
#  'Unbelievable',
#  'Dead to Me',
#  'When They See Us',
#  'Elite']

# %%
def top10SimMatrix(top10, titleVec, save=False):
    x = [i.lower() for i in top10]
    array = np.array([titleVec[title] for title in x])
    top10TvHeatMap = pd.DataFrame(columns=top10, index=top10, data = sklearn.metrics.pairwise.cosine_similarity(array))

    plt.figure(figsize=(10,6))
    sns.heatmap(top10TvHeatMap,annot=True, cbar=True, cmap='RdBu_r')
    plt.show()
    if save==True:
        plt.savefig('top10SimMatrix.png')

# %%
search('stranger things', tvshowDf)
# Out:
#                 title  \
# 1494  Stranger Things
#
#                                                                           genres  \
# 1494  drama,fantasy,horror,mystery,science-fiction,thriller,action-and-adventure
#
#       year  originals  \
# 1494  2016          1
#
#                                                                                                                                                                                                                             everything
# 1494  When a young boy vanishes, a small town uncovers a mystery involving secret experiments, terrifying supernatural forces, and one strange little girl. drama,fantasy,horror,mystery,science-fiction,thriller,action-and-adventure

# %%
search('the umbrella academy', tvshowDf)
# Out:
#                      title  \
# 1805  The Umbrella Academy
#
#                                                                        genres  \
# 1805  action-and-adventure,lgbtq,comedy,drama,fantasy,science-fiction,mystery
#
#       year  originals  \
# 1805  2019          1
#
#                                                                                                                                                                                                              everything
# 1805  A dysfunctional family of superheroes comes together to solve the mystery of their father's death, the threat of the apocalypse and more. action-and-adventure,lgbtq,comedy,drama,fantasy,science-fiction,mystery

# %%
top10SimMatrix(top10_tvshow, tvshowTitleVec)

# %%
tvshowTrailerIds = {'stranger things s1':'b9EkMc79ZSU',
                   'stranger things s2':'R1ZXOOLMJ8s',
                    'you s1':'ga1m0wjzscU',
                    'you s2':'xXBTImqyeU0',
                    'the umbrella academy s1':'0DAmWHxeoKw',
                    'the umbrella academy s2':'Me0eoCwLj-A',
                    
                   }

# %%
b9EkMc79ZSU

# %%
comments = get_1kcomments('b9EkMc79ZSU')
create_wordcloud(comments)
sent = sentiment(comments)
plot_sentiments(sent)
sent_count = sentiment_counts(sent)
show_sentiment_counts(sent_count)

# %%
youtubereq = youtube.videos().list(
        part="statistics",
        id="b9EkMc79ZSU")
res = youtubereq.execute()

# %%
res
# Out:
# {'kind': 'youtube#videoListResponse',
#  'etag': 'g6QIqEjGiGiSSuJObGnX0TU48pI',
#  'items': [{'kind': 'youtube#video',
#    'etag': 'JMsRq_uCzZyC7k8_vecxw21Afbg',
#    'id': 'b9EkMc79ZSU',
#    'statistics': {'viewCount': '4569854',
#     'likeCount': '45332',
#     'dislikeCount': '823',
#     'favoriteCount': '0',
#     'commentCount': '2432'}}],
#  'pageInfo': {'totalResults': 1, 'resultsPerPage': 1}}

# %%
movieDf.head()
# Out:
#                     title                               genres  year   type  \
# 0            1000 Mabrouk        comedy,drama,fantasy,thriller  2009  movie
# 1         1000 Rupee Note                                drama  2016  movie
# 2  100 Days of Loneliness                    documentary,drama  2018  movie
# 3              100 Meters               comedy,drama,biography  2016  movie
# 4     10 Days In Sun City  comedy,action-and-adventure,romance  2017  movie
#
#    originals  \
# 0          0
# 1          0
# 2          0
# 3          0
# 4          0
#
#                                                                                                                                                                                                                                                                                                                                                      everything
# ...

# %%
x = pd.read_csv('finalDataset_v2.csv')

# %%
x.drop('Unnamed: 0', axis=1)[['title','description']].iloc[0,:]
# Out:
# title                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   1000 Mabrouk
# ...

# %%
z = movieDf[['title','everything']].iloc[0,:].rename({'everything':'description'})

# %%
y = pd.DataFrame()
y[0] = x.drop('Unnamed: 0', axis=1)[['title','description']].iloc[0,:]
y[1] = z

# %%
y = y.transpose()
