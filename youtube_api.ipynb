# %%
from googleapiclient.discovery import build

api = 'AIzaSyD62jn_-RGNj0F0Uadgz78plOvfxVE8q28'

youtube = build('youtube','v3',developerKey=api)

# %%
request = youtube.commentThreads().list(
        part="snippet,replies",
        maxResults = 100,
        videoId="NfpXeLVzJIw")

# %%
response = request.execute()

# %%
list_of_comments = list()
for i in range(100):
    list_of_comments.append(response['items'][i]['snippet']['topLevelComment']['snippet']['textOriginal'])

# %%
list_of_comments
# Out:
# ["Imagine, 6'1 is the average height in my country.",
#  "abby's harsh words",
#  '*Being a SHORT MAN is harder than being  TALL WOMAN...* Change my mind',
#  'She is so beautiful  the tall girl.. Best movie',
#  "You think ur like is hard \n\n\n\nI've veen fat for my whole life, got friend zoned and broke sevral bones",
#  'I have 1 question...just 1...\nDoes height matter?',
#  'she was so tall',
#  'Tall Girl: Hey, do you want help on the test?\nPerson: n o e\nTall Girl: GoD DaMn IT I aM HuMaN tOo',
#  'This film is lame',
#  'It’s better then being a guy who’s a sophomore and 5’2 😭😭',
#  'Ok but the ending was so cute😭😭',
#  'And there are kids starving and dying of disease in poor countries and you act like you have the hardest life',
#  'Wait tall is not a disability',
#  '0:33 does this guy look like jordi',
#  "Jodie: I'm a high school junior wearing size 13 Nikes MENS size 13 Nikes BEAT THAT.\nCorona virus people :  *cough cough* This girls kidding right?",
# ...

# %%
response['items'][0]['snippet']['topLevelComment']['snippet']['textOriginal']
# Out:
# "Imagine, 6'1 is the average height in my country."

# %%
from pprint import pprint
len(response)
# Out:
# {'etag': 'czThiDfQZmp35WEV_MnxfK0AVlY',
#  'items': [{'etag': '2lm7Szj1ZIEKrmk_DiLj7Lh7V-0',
#             'id': 'Ugx1z6NbRsyt01D23sp4AaABAg',
#             'kind': 'youtube#commentThread',
#             'snippet': {'canReply': True,
#                         'isPublic': True,
#                         'topLevelComment': {'etag': '4S9CYj-G8kTA32MelDSSzgLmuzo',
#                                             'id': 'Ugx1z6NbRsyt01D23sp4AaABAg',
#                                             'kind': 'youtube#comment',
#                                             'snippet': {'authorChannelId': {'value': 'UCUVzMZfr6Um9Pcj5mrAJ_gQ'},
#                                                         'authorChannelUrl': 'http://www.youtube.com/channel/UCUVzMZfr6Um9Pcj5mrAJ_gQ',
#                                                         'authorDisplayName': "lil' "
#                                                                              'one',
# ...

# %%
req = youtube.videos().list(
        part="statistics",
        id="NfpXeLVzJIw")

# %%
res = req.execute()

# %%
res
# Out:
# {'kind': 'youtube#videoListResponse',
#  'etag': 'fgeQvIMsi87HlVhd4cjDSXSexFE',
#  'items': [{'kind': 'youtube#video',
#    'etag': 'iWnR-K7cdyhqhdZHuvOK1EoY2Z0',
#    'id': 'NfpXeLVzJIw',
#    'statistics': {'viewCount': '5571037',
#     'likeCount': '96318',
#     'dislikeCount': '15763',
#     'favoriteCount': '0',
#     'commentCount': '13659'}}],
#  'pageInfo': {'totalResults': 1, 'resultsPerPage': 1}}

# %%
import omdb
API_KEY = 42362875
omdb.set_default('apikey', API_KEY)

# %%
mute = omdb.get(title='mute',
        year = 2018,
        fullplot = True)

# %%
import pandas as pd

# %%
df = pd.DataFrame(data=[mute])

# %%
df1 = pd.DataFrame(data=[theSilence])

# %%
df.append(df1, ignore_index=True)
# Out:
#          title  year  rated     released  runtime  \
# 0         Mute  2018  TV-MA  23 Feb 2018  126 min
# 1  The Silence  2019  PG-13  10 Apr 2019   90 min
#
#                              genre          director  \
# 0        Mystery, Sci-Fi, Thriller      Duncan Jones
# 1  Drama, Horror, Sci-Fi, Thriller  John R. Leonetti
#
#                                               writer  \
# 0  Michael Robert Johnson (screenplay by), Duncan...
# 1  Carey Van Dyke (screenplay by), Shane Van Dyke...
#
#                                               actors  \
# 0  Levi Eisenblätter, Rosie Shaw, Eugen Bauder, L...
# 1  Stanley Tucci, Kiernan Shipka, Miranda Otto, K...
#
#                                                 plot  ... metascore  \
# 0  Berlin. Forty years from today. A roiling city...  ...        35
# 1  When the world is under attack from terrifying...  ...        25
#
#   imdb_rating imdb_votes    imdb_id   type          dvd box_office production  \
# ...

# %%
d = {'bird box': ['bird box',
  'the silence_2019',
  'dark places',
  'the forest of love',
  'the keeping hours',
  'how it ends',
  'cabin fever',
  'our house',
  'mute',
  'into the forest',
  'dark skies']}

# %%
x = omdb.get(title=d['bird box'][2],
                     fullplot=True)

# %%
for i in range(12):
    print(omdb.get(title=d['bird box'][2],
                     fullplot=True))
# Out:
# {'title': 'Dark Places', 'year': '2015', 'rated': 'R', 'released': '18 Jun 2015', 'runtime': '113 min', 'genre': 'Action, Drama, Mystery, Thriller', 'director': 'Gilles Paquet-Brenner', 'writer': 'Gilles Paquet-Brenner (written for the screen by), Gillian Flynn (novel)', 'actors': 'Charlize Theron, Sterling Jerins, Nicholas Hoult, Christina Hendricks', 'plot': 'Libby Day is a lifeless woman who survived the massacre of her family in their farmhouse in the countryside of Kansas when she was eight. She\'s been living on donations and lectures ever since. Thirty years ago, the police believed that a satanic cult was responsible for the murder of her mother and two sisters, and her brother Ben was convicted with her testimony in court. Today, however, an acquaintance, Lyle Wirth, invites Libby to visit "The Kill Club", where amateurs investigate famous crimes, and she finds that they believe Ben is innocent. Libby needs money and, in return, accepts to revisit the slaughter of her family
# ...
